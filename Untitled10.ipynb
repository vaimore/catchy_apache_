# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
import seaborn as sn
import matplotlib.pyplot as plt

df = pd.read_csv('V:/data.csv')
df.head()
# Out:
#            x1          x2  y
# 0 -119.366669  115.000000  1
# 1 -101.108045   97.777159  1
# 2 -130.278658  106.767654  1
# 3 -114.703415  101.195477  1
# 4 -119.366669  115.000000  1

# %%
df.shape
# Out:
# (2227, 3)

# %%
df = df.apply (pd.to_numeric, errors='coerce')
df = df.dropna()
df = df.reset_index(drop=True)

# %%
df
# Out:
#               x1            x2  y
# 0    -119.366669  1.150000e+02  1
# 1    -101.108045  9.777716e+01  1
# 2    -130.278658  1.067677e+02  1
# 3    -114.703415  1.011955e+02  1
# 4    -119.366669  1.150000e+02  1
# ...          ...           ... ..
# 2214   98.714112  8.964312e+01  0
# 2215   96.633331  9.100000e+01  0
# 2216   85.673940  1.038393e+02  0
# 2217   78.958862  7.860537e+01  0
# 2218  109.624009  1.000000e+08  0
#
# [2219 rows x 3 columns]

# %%
X = df[['x1','x2']]
X
# Out:
#               x1            x2
# 0    -119.366669  1.150000e+02
# 1    -101.108045  9.777716e+01
# 2    -130.278658  1.067677e+02
# 3    -114.703415  1.011955e+02
# 4    -119.366669  1.150000e+02
# ...          ...           ...
# 2214   98.714112  8.964312e+01
# 2215   96.633331  9.100000e+01
# 2216   85.673940  1.038393e+02
# 2217   78.958862  7.860537e+01
# 2218  109.624009  1.000000e+08
#
# [2219 rows x 2 columns]

# %%
y = df[['y']]
y
# Out:
#       y
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1
# ...  ..
# 2214  0
# 2215  0
# 2216  0
# 2217  0
# 2218  0
#
# [2219 rows x 1 columns]

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
clf = DecisionTreeClassifier()
clf = clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)

# %%
print("Accuracy: ",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy:  0.9369369369369369

# %%
from matplotlib import pyplot as plt
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier 
from sklearn import tree

# %%
clf = DecisionTreeClassifier(random_state=1234)
model = clf.fit(X, y)

# %%
text_representation = tree.export_text(clf)
print(text_representation)
# Out:
# |--- feature_0 <= -66.01
# |   |--- feature_1 <= -26.91
# |   |   |--- class: 0
# |   |--- feature_1 >  -26.91
# |   |   |--- class: 1
# |--- feature_0 >  -66.01
# |   |--- feature_1 <= 16.17
# |   |   |--- feature_0 <= 16.56
# |   |   |   |--- feature_1 <= -31.99
# |   |   |   |   |--- feature_0 <= 0.55
# |   |   |   |   |   |--- feature_0 <= -13.33
# |   |   |   |   |   |   |--- feature_1 <= -40.13
# |   |   |   |   |   |   |   |--- feature_0 <= -21.07
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_0 >  -21.07
# |   |   |   |   |   |   |   |   |--- feature_0 <= -20.99
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_0 >  -20.99
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= -19.23
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= -19.36
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  -19.36
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  -19.23
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_1 >  -40.13
# |   |   |   |   |   |   |   |--- feature_1 <= -39.78
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_1 >  -39.78
# |   |   |   |   |   |   |   |   |--- feature_0 <= -23.11
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= -24.11
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= -34.45
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  -34.45
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  -24.11
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_0 >  -23.11
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_0 >  -13.33
# |   |   |   |   |   |   |--- feature_1 <= -39.49
# |   |   |   |   |   |   |   |--- feature_1 <= -51.30
# |   |   |   |   |   |   |   |   |--- feature_0 <= -3.33
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_0 >  -3.33
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= -2.91
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  -2.91
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_1 >  -51.30
# |   |   |   |   |   |   |   |   |--- feature_1 <= -45.15
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_1 >  -45.15
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= -41.78
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  -41.78
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= -5.89
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  -5.89
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_1 >  -39.49
# |   |   |   |   |   |   |   |--- feature_0 <= -11.67
# |   |   |   |   |   |   |   |   |--- feature_1 <= -34.59
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_1 >  -34.59
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_0 >  -11.67
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_0 >  0.55
# |   |   |   |   |   |--- feature_0 <= 15.13
# |   |   |   |   |   |   |--- feature_1 <= -32.79
# |   |   |   |   |   |   |   |--- feature_0 <= 10.42
# |   |   |   |   |   |   |   |   |--- feature_0 <= 9.92
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= -54.71
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= -73.24
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  -73.24
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  -54.71
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_0 >  9.92
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_0 >  10.42
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_1 >  -32.79
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_0 >  15.13
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- feature_1 >  -31.99
# |   |   |   |   |--- feature_0 <= 2.07
# |   |   |   |   |   |--- feature_1 <= -3.24
# |   |   |   |   |   |   |--- feature_0 <= -5.31
# |   |   |   |   |   |   |   |--- feature_0 <= -29.84
# |   |   |   |   |   |   |   |   |--- feature_1 <= -22.11
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= -27.31
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  -27.31
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_1 >  -22.11
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= -13.70
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= -14.47
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  -14.47
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  -13.70
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_0 >  -29.84
# |   |   |   |   |   |   |   |   |--- feature_1 <= -28.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= -31.13
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  -31.13
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_1 >  -28.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= -11.11
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= -8.78
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  -8.78
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  -11.11
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= -20.87
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  -20.87
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_0 >  -5.31
# |   |   |   |   |   |   |   |--- feature_0 <= -2.00
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_0 >  -2.00
# |   |   |   |   |   |   |   |   |--- feature_0 <= -0.48
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_0 >  -0.48
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_1 >  -3.24
# |   |   |   |   |   |   |--- feature_0 <= -6.87
# |   |   |   |   |   |   |   |--- feature_0 <= -25.59
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_0 >  -25.59
# |   |   |   |   |   |   |   |   |--- feature_0 <= -24.16
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_0 >  -24.16
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_0 >  -6.87
# |   |   |   |   |   |   |   |--- feature_1 <= 7.34
# |   |   |   |   |   |   |   |   |--- feature_1 <= -2.32
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_1 >  -2.32
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= -0.89
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  -0.89
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= -4.77
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  -4.77
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |--- feature_1 >  7.34
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_0 >  2.07
# |   |   |   |   |   |--- feature_1 <= -21.52
# |   |   |   |   |   |   |--- feature_1 <= -25.52
# |   |   |   |   |   |   |   |--- feature_0 <= 10.18
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_0 >  10.18
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_1 >  -25.52
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_1 >  -21.52
# |   |   |   |   |   |   |--- feature_0 <= 13.28
# |   |   |   |   |   |   |   |--- feature_1 <= -0.24
# |   |   |   |   |   |   |   |   |--- feature_1 <= -13.57
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 4.06
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  4.06
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 7.13
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  7.13
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- feature_1 >  -13.57
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_1 >  -0.24
# |   |   |   |   |   |   |   |   |--- feature_1 <= 3.68
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_1 >  3.68
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 4.58
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  4.58
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 6.94
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  6.94
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_0 >  13.28
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |--- feature_0 >  16.56
# |   |   |   |--- feature_1 <= -16.40
# |   |   |   |   |--- feature_1 <= -39.18
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_1 >  -39.18
# |   |   |   |   |   |--- feature_1 <= -38.86
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_1 >  -38.86
# |   |   |   |   |   |   |--- feature_0 <= 20.99
# |   |   |   |   |   |   |   |--- feature_1 <= -25.62
# |   |   |   |   |   |   |   |   |--- feature_1 <= -33.37
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_1 >  -33.37
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 18.97
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  18.97
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_1 >  -25.62
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_0 >  20.99
# |   |   |   |   |   |   |   |--- feature_1 <= -32.34
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_1 >  -32.34
# |   |   |   |   |   |   |   |   |--- feature_1 <= -30.32
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 26.18
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  26.18
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_1 >  -30.32
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- feature_1 >  -16.40
# |   |   |   |   |--- feature_1 <= -1.26
# |   |   |   |   |   |--- feature_1 <= -10.83
# |   |   |   |   |   |   |--- feature_0 <= 24.63
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_0 >  24.63
# |   |   |   |   |   |   |   |--- feature_0 <= 34.75
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_0 >  34.75
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_1 >  -10.83
# |   |   |   |   |   |   |--- feature_0 <= 31.11
# |   |   |   |   |   |   |   |--- feature_0 <= 21.66
# |   |   |   |   |   |   |   |   |--- feature_1 <= -4.64
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_1 >  -4.64
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_0 >  21.66
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_0 >  31.11
# |   |   |   |   |   |   |   |--- feature_1 <= -6.68
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_1 >  -6.68
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_1 >  -1.26
# |   |   |   |   |   |--- feature_1 <= 0.81
# |   |   |   |   |   |   |--- feature_1 <= 0.01
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_1 >  0.01
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_1 >  0.81
# |   |   |   |   |   |   |--- class: 0
# |   |--- feature_1 >  16.17
# |   |   |--- feature_0 <= 1.65
# |   |   |   |--- feature_0 <= -6.92
# |   |   |   |   |--- feature_0 <= -23.08
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_0 >  -23.08
# |   |   |   |   |   |--- feature_0 <= -22.64
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_0 >  -22.64
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- feature_0 >  -6.92
# |   |   |   |   |--- feature_0 <= -4.15
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_0 >  -4.15
# |   |   |   |   |   |--- class: 1
# |   |   |--- feature_0 >  1.65
# |   |   |   |--- feature_0 <= 6.99
# |   |   |   |   |--- feature_0 <= 6.29
# |   |   |   |   |   |--- feature_1 <= 22.21
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_1 >  22.21
# |   |   |   |   |   |   |--- feature_1 <= 23.61
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_1 >  23.61
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_0 >  6.29
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- feature_0 >  6.99
# |   |   |   |   |--- feature_0 <= 21.53
# |   |   |   |   |   |--- feature_0 <= 20.37
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_0 >  20.37
# |   |   |   |   |   |   |--- feature_0 <= 20.74
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_0 >  20.74
# |   |   |   |   |   |   |   |--- feature_0 <= 21.17
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_0 >  21.17
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_0 >  21.53
# |   |   |   |   |   |--- class: 0

# %%
with open('Decision_tree.log','w')as fout:
    fout.write(text_representation)

# %%
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(clf, 
                   feature_names= X,  
                   class_names= y,
                   filled=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\user\python\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-ae54766a1b70> in <module>
#       1 fig = plt.figure(figsize=(25,20))
# ----> 2 _ = tree.plot_tree(clf,
#       3                    feature_names= X,
#       4                    class_names= y,
#       5                    filled=True)
#
# c:\users\user\python\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# c:\users\user\python\lib\site-packages\sklearn\tree\_export.py in plot_tree(decision_tree, max_depth, feature_names, class_names, label, filled, impurity, node_ids, proportion, rotate, rounded, precision, ax, fontsize)
#     192         proportion=proportion, rotate=rotate, rounded=rounded,
#     193         precision=precision, fontsize=fontsize)
# --> 194     return exporter.export(decision_tree, ax=ax)
#     195
#     196
#
# c:\users\user\python\lib\site-packages\sklearn\tree\_export.py in export(self, decision_tree, ax)
#     582         ax.clear()
#     583         ax.set_axis_off()
# --> 584         my_tree = self._make_tree(0, decision_tree.tree_,
#     585                                   decision_tree.criterion)
#     586         draw_tree = buchheim(my_tree)
#
# c:\users\user\python\lib\site-packages\sklearn\tree\_export.py in _make_tree(self, node_id, et, criterion, depth)
#     563         # traverses _tree.Tree recursively, builds intermediate
#     564         # "_reingold_tilford.Tree" object
# --> 565         name = self.node_to_str(et, node_id, criterion=criterion)
#     566         if (et.children_left[node_id] != _tree.TREE_LEAF
#     567                 and (self.max_depth is None or depth <= self.max_depth)):
#
# c:\users\user\python\lib\site-packages\sklearn\tree\_export.py in node_to_str(self, tree, node_id, criterion)
#     285             # Always write node decision criteria, except for leaves
#     286             if self.feature_names is not None:
# --> 287                 feature = self.feature_names[tree.feature[node_id]]
#     288             else:
#     289                 feature = "X%s%s%s" % (characters[1],
#
# c:\users\user\python\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# c:\users\user\python\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 0
